# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import plotly.graph_objects as go
import joblib

# %% [markdown]
# ### Read and Clean Data

# %%
#read csv using pandas
df = pd.read_csv('Bank_Predictions.csv')
df.head()
# Out:
#    Number  Customer_ID Last_Name  Cr_Score Location  Gender  Age  History  \
# 0       1     15634602  Hargrave       619   France  Female   42        2
# 1       2     15647311      Hill       608    Spain  Female   41        1
# 2       3     15619304      Onio       502   France  Female   42        8
# 3       4     15701354      Boni       699   France  Female   39        1
# 4       5     15737888  Mitchell       850    Spain  Female   43        2
#
#    Current_Balance  Num_Of_Products  Has_CrCard  IsActiveMember  \
# 0             0.00                1           1               1
# 1         83807.86                1           0               1
# 2        159660.80                3           1               0
# 3             0.00                2           0               0
# 4        125510.82                1           1               1
#
#    Customer_Salary  Acc_Closed
# 0        101348.88           1
# 1        112542.58           0
# 2        113931.57           1
# 3         93826.63           0
# 4         79084.10           0

# %%
#examine shape of data along with column types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Number           10000 non-null  int64
#  1   Customer_ID      10000 non-null  int64
#  2   Last_Name        10000 non-null  object
#  3   Cr_Score         10000 non-null  int64
#  4   Location         10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   History          10000 non-null  int64
#  8   Current_Balance  10000 non-null  float64
#  9   Num_Of_Products  10000 non-null  int64
#  10  Has_CrCard       10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  Customer_Salary  10000 non-null  float64
#  13  Acc_Closed       10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
#examine the predicted column to ensure data integrity
df.Acc_Closed.value_counts()
# Out:
# Acc_Closed
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
#drop irrelevant columns
df_dropped = df.drop(columns=['Number','Customer_ID','Last_Name'])


#assign variables
x = df_dropped.drop('Acc_Closed',axis=1)
y = df_dropped.Acc_Closed


#encode categorical variables and drop columns that could cause multicollinearity
x = pd.get_dummies(x, columns=['Location','Gender'], drop_first=True)
print("New X Shape: ",x.shape)
print("New column types post encoding:\n", x.dtypes)
# Out:
# New X Shape:  (10000, 11)
# New column types post encoding:
#  Cr_Score              int64
# Age                   int64
# History               int64
# Current_Balance     float64
# Num_Of_Products       int64
# Has_CrCard            int64
# IsActiveMember        int64
# Customer_Salary     float64
# Location_Germany       bool
# Location_Spain         bool
# Gender_Male            bool
# dtype: object

# %%
#splitting train and test groups, stratifying to ensure even split in train and test
x_train, x_test, y_train, y_test = train_test_split(x
                                                    ,y
                                                    ,test_size=.2
                                                    ,random_state=42
                                                    ,stratify=y
                                                )

#ensuring split 
print('x_train:', x_train.shape)
print('x_test', x_test.shape)
# Out:
# x_train: (8000, 11)
# x_test (2000, 11)

# %%
#scaling features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

print('x_train shape: ',x_train.shape)
# Out:
# x_train shape:  (8000, 11)

# %% [markdown]
# ### Build ANN Model

# %%
#initializing uising a sequential model as it is the simplest and non-linear topography isnt needed
model = Sequential()
#input layer + first hidden layer, relu is applied to each nodes output
model.add(Dense(units=16, activation='relu', input_dim=x_train.shape[1]))
#second hidden layer and again relu
model.add(Dense(units=8, activation='relu'))
#output layer (binary classification -> 1 neuron, sigmoid)
model.add(Dense(units=1,activation='sigmoid'))
#compile model and loss is binary and adam adjusts weights individually
model.compile(
    optimizer='adam'
    ,loss='binary_crossentropy'
    ,metrics=['accuracy']
)
model.summary()
# Out:
# c:\Users\cuomo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 337 (1.32 KB)
#  Trainable params: 337 (1.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ###
# Epoch 33/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8650 - loss: 0.3272 - val_accuracy: 0.8645 - val_loss: 0.3405
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8635 - loss: 0.3265 - val_accuracy: 0.8635 - val_loss: 0.3417
# Epoch 35/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8644 - loss: 0.3265 - val_accuracy: 0.8635 - val_loss: 0.3415
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8636 - loss: 0.3265 - val_accuracy: 0.8620 - val_loss: 0.3411
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8643 - loss: 0.3262 - val_accuracy: 0.8645 - val_loss: 0.3408
# Epoch 38/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8645 - loss: 0.3258 - val_accuracy: 0.8635 - val_loss: 0.3415
# Epoch 39/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8637 - loss: 0.3259 - val_accuracy: 0.8655 - val_loss: 0.3415
# Epoch 40/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8643 - loss: 0.3256 - val_accuracy: 0.8630 - val_loss: 0.3411
# Epoch 41/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8650 - loss: 0.3256 - val_accuracy: 0.8620 - val_loss: 0.3410
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8659 - loss: 0.3252 - val_accuracy: 0.8605 - val_loss: 0.3415
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8641 - loss: 0.3250 - val_accuracy: 0.8635 - val_loss: 0.3416
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8631 - loss: 0.3247 - val_accuracy: 0.8620 - val_loss: 0.3413
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8649 - loss: 0.3241 - val_accuracy: 0.8615 - val_loss: 0.3453
# Epoch 46/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8631 - loss: 0.3246 - val_accuracy: 0.8615 - val_loss: 0.3420
# Epoch 47/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8637 - loss: 0.3241 - val_accuracy: 0.8600 - val_loss: 0.3415
# Epoch 48/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8652 - loss: 0.3243 - val_accuracy: 0.8630 - val_loss: 0.3430
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8637 - loss: 0.3247 - val_accuracy: 0.8635 - val_loss: 0.3424
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8648 - loss: 0.3243 - val_accuracy: 0.8600 - val_loss: 0.3433

# %% [markdown]
# ### Reporting

# %%
#predicting probabilities
y_prob = model.predict(x_test)
#convert probs to bianry using .5 threshold
y_pred = (y_prob >= .5).astype(int).ravel()

print('test accuracy:', accuracy_score(y_test,y_pred))

cm = confusion_matrix(y_test,y_pred)
print('\nConfusion Matrix:\n',cm)
print('\nClassification Report:\n',classification_report(y_test,y_pred,digits=4))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# test accuracy: 0.86
#
# Confusion Matrix:
#  [[1531   62]
#  [ 218  189]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8754    0.9611    0.9162      1593
#            1     0.7530    0.4644    0.5745       407
#
#     accuracy                         0.8600      2000
#    macro avg     0.8142    0.7127    0.7453      2000
# weighted avg     0.8505    0.8600    0.8467      2000

# %%
#model accuracy plot
fig = go.Figure()

fig.add_trace(go.Scatter(
    y=history.history['accuracy'],
    mode='lines',
    name='Train Accuracy'
))

fig.add_trace(go.Scatter(
    y=history.history['val_accuracy'],
    mode='lines',
    name='Validation Accuracy'
))

fig.update_layout(
    title='Model Accuracy',
    xaxis_title='Epoch',
    yaxis_title='Accuracy'
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    y=history.history['loss'],
    mode='lines',
    name='Train Loss'
))

fig.add_trace(go.Scatter(
    y=history.history['val_loss'],
    mode='lines',
    name='Validation Loss'
))

fig.update_layout(
    title='Model Loss',
    xaxis_title='Epoch',
    yaxis_title='Loss'
)

fig.show()

# %% [markdown]
# ### Saving Trained Model

# %%
# Save trained ANN
model.save("ann_bank_model.h5")

# Save scaler
joblib.dump(scaler, "scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['scaler.pkl']
